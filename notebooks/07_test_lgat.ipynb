# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

from models.backbone.modules.lgat import LGAT
import torch

# ConvMixer's actual feature-map shape before pooling: dim=128, 300/patch10 -> 30x30 grid
x = torch.randn(2, 128, 30, 30)

lgat = LGAT(dim=128)
g = lgat(x)

print("Input shape: ", x.shape)
print("Output shape:", g.shape)   # expect [2, 128]
assert g.shape == (2, 128)
print("Param count:", sum(p.numel() for p in lgat.parameters()))
print("\nLGAT test: PASSED")
# Out:
# Input shape:  torch.Size([2, 128, 30, 30])
# Output shape: torch.Size([2, 128])
# Param count: 49664
#
# LGAT test: PASSED

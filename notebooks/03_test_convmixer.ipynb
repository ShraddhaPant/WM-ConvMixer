# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))  # notebooks/ -> project root

from models.backbone.convmixer import ConvMixer
from models.backbone.modules.dataset import ELPVDataset
import torch

train_ds = ELPVDataset(split="train")

model = ConvMixer(in_channels=1, dim=128, depth=8, kernel_size=9,
                   patch_size=10, num_classes=4)

x, y = train_ds[0]
x = x.unsqueeze(0)  # add batch dim: [1, 1, 300, 300]

out = model(x)
print("Input shape:", x.shape)
print("Output shape:", out.shape)   # expect [1, 4]
print("Param count:", sum(p.numel() for p in model.parameters()))
# Out:
# Input shape: torch.Size([1, 1, 300, 300])
# Output shape: torch.Size([1, 4])
# Param count: 233860

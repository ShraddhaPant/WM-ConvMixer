# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

from models.baselines.mobilenet_baseline import LightweightCNNBaseline
import torch

CONVMIXER_PARAMS = 233_860

for w in [0.1, 0.15, 0.2, 0.25, 0.35, 0.5]:
    m = LightweightCNNBaseline(in_channels=1, num_classes=4, width_mult=w)
    n_params = sum(p.numel() for p in m.parameters())
    diff = n_params - CONVMIXER_PARAMS
    print(f"width_mult={w:<5} params={n_params:>8,}  (diff: {diff:+,})")
# Out:
# width_mult=0.1   params=  91,060  (diff: -142,800)
# width_mult=0.15  params= 139,476  (diff: -94,384)
# width_mult=0.2   params= 195,316  (diff: -38,544)
# width_mult=0.25  params= 243,092  (diff: +9,232)
# width_mult=0.35  params= 400,964  (diff: +167,104)
# width_mult=0.5   params= 692,516  (diff: +458,656)
